# %%
# Based on https://pythainlp.github.io/tutorials/notebooks/word2vec_examples.html
# %matplotlib inline

# %%
from gensim.models import KeyedVectors
from pythainlp import word_vector
model = word_vector.get_model()

# %%
model.get_vector("ปวงชน")
# Out:
# array([ 1.13620e-02, -1.18360e-02, -5.00330e-02, -7.76300e-03,
#        -5.01730e-02,  3.69930e-02, -4.73020e-02,  8.39960e-02,
#        -1.42236e-01,  9.77920e-02, -2.49444e-01,  4.34180e-02,
#        -3.90409e-01, -6.70210e-02,  4.43980e-02,  5.45400e-03,
#         3.29360e-02,  2.72674e-01,  6.90000e-05,  2.77999e-01,
#         6.61500e-03,  2.57330e-02, -2.37170e-02,  9.50030e-02,
#        -8.70500e-02, -3.07510e-02,  9.51600e-03, -2.42220e-02,
#        -5.64820e-02, -3.48857e-01,  3.76890e-02, -8.84190e-02,
#         9.27230e-02, -1.45094e-01, -5.04850e-02, -8.31070e-02,
#         2.35790e-02, -1.05891e-01, -8.88200e-03, -8.80220e-02,
#        -2.63260e-02, -1.48040e-02,  9.27890e-02,  1.23720e-02,
#         5.30090e-02,  1.51410e-02, -8.23700e-03,  3.47340e-02,
#        -7.94290e-02,  9.07610e-02,  4.04330e-02, -1.10530e-01,
#        -3.45730e-02,  5.24860e-02, -6.67800e-02, -9.81870e-02,
#        -4.58630e-02, -5.20110e-02, -3.84600e-03, -1.09199e-01,
# ...

# %%
model.most_similar(positive=["ปวงชน"])
# Out:
# [('พสกนิกร', 0.7351939678192139),
#  ('ส่วนรวม', 0.6746099591255188),
#  ('มวลชน', 0.6676229238510132),
#  ('มาตุภูมิ', 0.6535676717758179),
#  ('ชาวโลก', 0.6291572451591492),
#  ('ทุกฝ่าย', 0.6284131407737732),
#  ('เทิดทูน', 0.6035460829734802),
#  ('ความเสมอภาค', 0.5909103751182556),
#  ('เผด็จ', 0.5875926613807678),
#  ('ชอบธรรม', 0.587381899356842)]

# %%
model.most_similar(positive=["ประชาธิปไตย"], negative=["ประเทศไทย"])
# Out:
# [('เสรีนิยม', 0.37199294567108154),
#  ('สังคมนิยม', 0.36512643098831177),
#  ('เผด็จการ', 0.3346679210662842),
#  ('หุ่นเชิด', 0.3138933479785919),
#  ('ฝ่ายซ้าย', 0.31126150488853455),
#  ('ปฏิวัติ', 0.3029947280883789),
#  ('ยุติธรรม', 0.2933213710784912),
#  ('อนุรักษนิยม', 0.2893778681755066),
#  ('ราชาธิปไตย', 0.2876969277858734),
#  ('เผด็จ', 0.2819489538669586)]
